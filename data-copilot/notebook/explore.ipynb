# %%
import pandas as pd 
import numpy as np 
import os
import json

# %%
df = pd.read_csv('../data/sales_sample.csv')

# %%
df.shape
# Out:
# (20, 7)

# %%
df.describe().loc['mean'].to_dict()
# Out:
# {'Order_ID': 1010.5,
#  'Sales_Volume': 11.75,
#  'Unit_Price': 36.4165,
#  'Revenue': 206.5885}

# %%
((df.isnull().sum()/len(df))*100).to_dict()
# Out:
# {'Order_ID': 0.0,
#  'Product_ID': 0.0,
#  'Date': 0.0,
#  'Region': 0.0,
#  'Sales_Volume': 0.0,
#  'Unit_Price': 0.0,
#  'Revenue': 0.0}

# %%
output_file="../reports/eda_report.html"

print(os.path.dirname(output_file))
# Out:
# ../reports

# %%
import requests

prompt = "give me information about advancements in AI"
messages = [{"role":"user","content":prompt}]
response = requests.post(
    "http://127.0.0.1:11434/api/chat",
    json={"model":"gemma3:1b","messages" : messages},
    stream=True
)
print(response)
# Out:
# <Response [200]>

# %%
output = ""
for line in response.iter_lines():
    # print(json.loads(line))
    obj = json.loads(line)
    output += obj['message']['content']

print(output)
# Out:
# Okay, let's dive into the exciting world of AI advancements! It’s a rapidly evolving field, so here’s a breakdown of key areas and recent progress, categorized for clarity:
#
# **1. Large Language Models (LLMs) - The Current Reign:**
#
# * **What They Are:** LLMs like GPT-4, Gemini, Claude, and Llama are the most visible and impactful advancements right now. They're trained on massive datasets of text and code, allowing them to:
#     * **Generate Text:**  Write articles, poems, scripts, code, summaries, and more.
#     * **Translate Languages:** More accurate and nuanced than previous models.
#     * **Answer Questions:**  Provide informative answers to a wide range of questions.
#     * **Chat:** Engage in coherent and contextually relevant conversations.
# * **Recent Advancements:**
#     * **Multimodality:** LLMs are increasingly capable of understanding and generating across multiple modalities – text, images, audio, and video. Gemini is a prime example of this.
# ...

# %%
prompt = "give me information about advancements in AI"
messages = [{"role":"user","content":prompt}]
response = requests.post(
    "http://127.0.0.1:11434/api/chat",
    json={"model":"gemma2:1b","messages" : messages}
)
print(response.json()['response'])
messages.append({"role":"assistant","content":response.json()['response']})

# %%
response.status_code
# Out:
# 200

# %%
print(response.json()['response'])
# Out:
# Okay, let's dive into the exciting and rapidly evolving world of AI advancements! It's a huge field with breakthroughs happening constantly. Here's a breakdown of key areas, categorized for easier understanding, with current trends and some key examples:
#
# **1. Large Language Models (LLMs) – The Current Reign**
#
# * **What they are:** LLMs are the hottest area right now. They're AI models trained on massive datasets of text and code, allowing them to understand, generate, and manipulate human language with remarkable fluency. Examples include:
#     * **GPT-4 (OpenAI):** The most advanced model currently available, known for its improved reasoning, creativity, and ability to handle complex instructions.
#     * **Gemini (Google):** Google's flagship LLM, designed to be multimodal, meaning it can handle text, images, audio, and video.
#     * **Claude (Anthropic):** Focuses on safety and helpfulness, designed to be less prone to generating harmful outputs.
# * **Advancements:**
# ...
